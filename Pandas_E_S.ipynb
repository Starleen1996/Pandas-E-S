# %% [markdown]
# <a href="https://colab.research.google.com/github/Starleen1996/Pandas-E-S/blob/main/Pandas_E_S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1 - Leyendo Archivos CSV

# %% [markdown]
# ## Importando Archivos CSV

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/Starleen1996/Pandas-E-S/main/manzanas.csv'
datos = pd.read_csv(url)  # Agrega sep=';' si tu archivo usa punto y coma

# %%
datos.head()
# Out:
#       Unnamed: 0  1.2013  2.2013  3.2013  4.2013  5.2013  6.2013  7.2013  \
# 0          Moscu   79.72   81.08   79.68   79.80   80.63   80.80   80.28
# 1   Kaliningrado   42.67   44.37   44.73   46.75     NaN   51.59   57.80
# 2    Petersburgo   62.55   62.73   63.43   63.83   66.06   69.22   72.07
# 3      Krasnodar   48.26   51.01   50.91   53.94   61.27   65.44   56.51
# 4  Ekaterimburgo   71.25   71.35   70.90   71.92   72.91   74.39   73.10
#
#    8.2013  9.2013  ...  6.2019  7.2019  8.2019  9.2019  10.2019  11.2019  \
# 0   78.99   76.77  ...  116.91  125.29  123.94  113.03   102.19    97.83
# 1   62.14   56.76  ...   79.20   80.85   85.33   75.02    77.95    78.98
# 2   69.31   65.18  ...  115.35  123.03  123.08  109.71    97.22    95.75
# 3   53.00   43.87  ...  102.01  116.12   92.06   82.70    66.62    68.11
# 4   70.24   69.12  ...  121.68  125.32  123.41  108.48    98.73    96.25
#
#    12.2019  1.2020  2.2020  3.2020
# 0   101.07  103.44  108.23  110.28
# ...

# %%
datos_seleccion = datos = pd.read_csv(url, usecols=['1.2013', '2.2013']) # devuelve las columnas 1 y 2
datos_seleccion
# Out:
#    1.2013  2.2013
# 0   79.72   81.08
# 1   42.67   44.37
# 2   62.55   62.73
# 3   48.26   51.01
# 4   71.25   71.35

# %%
datos_seleccion = datos = pd.read_csv(url, usecols=[0,1,2 ]) # Devuelve todas las filas , solo con las columnas 0 , 1 y 2
datos_seleccion
# Out:
#       Unnamed: 0  1.2013  2.2013
# 0          Moscu   79.72   81.08
# 1   Kaliningrado   42.67   44.37
# 2    Petersburgo   62.55   62.73
# 3      Krasnodar   48.26   51.01
# 4  Ekaterimburgo   71.25   71.35

# %% [markdown]
# ## Guardar Archivos CSV

# %%
datos_seleccion.to_csv('datos_manzanas.csv', index=False) # Guardar el archivo sin el indice

# %%
informacion_manzanas = pd.read_csv('datos_manzanas.csv') # Leer el archivo
informacion_manzanas
# Out:
#       Unnamed: 0  1.2013  2.2013
# 0          Moscu   79.72   81.08
# 1   Kaliningrado   42.67   44.37
# 2    Petersburgo   62.55   62.73
# 3      Krasnodar   48.26   51.01
# 4  Ekaterimburgo   71.25   71.35

# %% [markdown]
# ## Hagamos lo que hicimos

# %%
informacion = pd.read_csv('datos_sus.csv', sep=';', encoding='ISO-8859-1', skiprows=3, skipfooter = 9, engine='python')

informacion
# Out:
#    Unidade da Federação      2008/Jan      2008/Fev      2008/Mar  \
# 0              Rondônia    1388528,39    2931283,42    1541682,52
# 1                  Acre     902416,00    1497206,26    1794028,48
# 2              Amazonas    4735529,42    7118990,57    8196635,49
# 3               Roraima     657889,53     777939,31     718688,03
# 4                  Pará   18864744,11   19553758,20   21937342,70
# 5                 Amapá    1120973,34    1268740,33     974651,24
# 6             Tocantins    3441592,69    4985688,85    6205612,60
# 7              Maranhão   10723506,39   13559679,41   13985142,36
# 8                 Piauí    7985142,43   10079928,25   10298372,45
# 9                 Ceará   15539821,90   25735101,55   28724625,75
# 10  Rio Grande do Norte    5947814,08    9509755,83   10352238,59
# 11              Paraíba   10723002,45   11386274,47   12053643,87
# 12           Pernambuco   14393949,89   24181400,95   29991302,71
# ...

# %% [markdown]
# ## Leyendo Archivos de Excel

# %% [markdown]
# #### Importando archivos excel

# %%
import pandas as pd

# %%
archivo = 'emisiones_CO2.xlsx' #Nombre Arcchivo de excel

# %%
archivo_CO2= pd.read_excel(archivo) # Permite traer un libro de excel
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4-2044848483.py in <cell line: 0>()
# ----> 1 archivo_CO2= pd.read_excel(archivo)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
# ...

# %%
pd.ExcelFile(archivo).sheet_names # Sirve para visualizar las hojas que tiene un libro de excel
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-5-3842007929.py in <cell line: 0>()
# ----> 1 pd.ExcelFile(archivo).sheet_names
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548                 ext = "xls"
#    1549             else:
# -> 1550                 ext = inspect_excel_format(
#    1551                     content_or_path=path_or_buffer, storage_options=storage_options
#    1552                 )
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1400         content_or_path = BytesIO(content_or_path)
#    1401
# -> 1402     with get_handle(
#    1403         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404     ) as handle:
#
# ...

# %% [markdown]
# ## Parametros de la funcion read_excel

# %% [markdown]
# [Documentación Read_Excel](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html)

# %%
percapita = pd.read_excel(archivo, sheet_name='Emisiones_per_capita') # Se trae la información de la hoja Emisiones percapita, del libro llamado archivo
percapita

# %%
percatipa.head() # Muestra los datos

# %% [markdown]
# #### Generar intervalos de datos para columnas

# %%
intervalo = pd.read_excel(archivo, sheet_name='Emisiones CO2', usecols= 'A:D ') # Se trae la información de la hoja Emisiones percapita, del libro llamado archivo y selecciona intervalor de la columna A a la D (A:D)

# %%
intervalo

# %% [markdown]
# #### Generar intervalos de datos para filas

# %%
intervalo_2 = pd.read_excel(archivo, sheet_name='Emisiones CO2', usecols= 'A:D', nrows= 10)  # Se trae la información de la hoja Emisiones percapita, del libro llamado archivo y selecciona intervalor de la columna A a la D (A:D) y selecciona las 2 primeras filas

# %%
intervalo_2

# %% [markdown]
# #### Escribiendo Archivos Excel

# %%
intervalo.to_excel('CO2_per_capita.xlsx', index= False)  # Se exporta la información sin el indice

# %%
pd.read_excel('CO2_per_capita.xlsx') # Se lee el archivo

# %% [markdown]
# #### Leyendo datos de google sheet

# %% [markdown]
# [link](https://docs.google.com/spreadsheets/d/1t1ISVxvnQTm8sVLod6TvmwEAMEOt6DMum74ry9EJ-n0/edit?usp=sharing)

# %%
sheet_id= '1t1ISVxvnQTm8sVLod6TvmwEAMEOt6DMum74ry9EJ-n0   # Identificador de excel'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'
# sirve para sincronizar el googlesheet con el google colab -  /gviz/tq
# tqx=out:csv' formato de salida que quiero leer en google colab

# %%
datos_co2_sheets= pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# /tmp/ipython-input-8-2033980511.py in <cell line: 0>()
# ----> 1 datos_co2_sheets= pd.read_csv(url)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
sheet_id = '1t1ISVxvnQTm8sVLod6TvmwEAMEOt6DMum74ry9EJ-n0'.strip()  # elimina espacios extra
sheet_name = 'Sheet1'  # ← pon aquí el nombre real de la pestaña

url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}' # Se muestra la información de la hoja "Sheet1"

# Leer el archivo
import pandas as pd
datos_co2_sheets = pd.read_csv(url)

# %%
pd.read_csv(url)
# Out:
#    YEAR  TYPE OF SURGERY     REGION  TYPE OF IMPLANT               TDS   \
# 0    NaN      ORTHOGNTHIC  OCCIDENTE              NaN  general feedback
# 1    NaN      ORTHOGNTHIC     CENTRO              NaN  general feedback
# 2    NaN      ORTHOGNTHIC     CENTRO              NaN  general feedback
# 3    NaN   RECONSTRUCTION  OCCIDENTE    anaplastology          TDS-5300
# 4    NaN      ORTHOGNTHIC  OCCIDENTE              NaN  general feedback
# 5    NaN              TMJ     CENTRO  TMJ replacement  general feedback
# 6    NaN   RECONSTRUCTION  ANTIOQUIA          general  general feedback
# 7    NaN              NaN        NaN              NaN               NaN
# 8    NaN              NaN        NaN              NaN               NaN
# 9    NaN              NaN        NaN              NaN               NaN
#
#                          SURGEON        Root source      DATE   \
# 0          CARLOS ENRIQUE FONSECA            farming       NaN
# ...

# %%
datos_co2_sheets.head(4)
# Out:
#    YEAR  TYPE OF SURGERY     REGION  TYPE OF IMPLANT               TDS   \
# 0    NaN      ORTHOGNTHIC  OCCIDENTE              NaN  general feedback
# 1    NaN      ORTHOGNTHIC     CENTRO              NaN  general feedback
# 2    NaN      ORTHOGNTHIC     CENTRO              NaN  general feedback
# 3    NaN   RECONSTRUCTION  OCCIDENTE    anaplastology          TDS-5300
#
#                      SURGEON        Root source      DATE   \
# 0      CARLOS ENRIQUE FONSECA            farming       NaN
# 1                 Dr. de Leon            farming    Feb 11
# 2  Dr. Carlos Gregorio Torres  complaint/farming  March 25
# 3        Luis Fernando Rincón          complaint  March 26
#
# ...

# %% [markdown]
# ## Haga lo que hicimos

# %% [markdown]
# #### Leyendo datos de google sheet.
# #### Link [Link_Acceso](https://docs.google.com/spreadsheets/d/1ASdngScxhjs9sO9RhI0TB3kFa2NAojI8Xg21OQfZW9c/edit?usp=sharing)

# %%
sheet_ID_2 = '1ASdngScxhjs9sO9RhI0TB3kFa2NAojI8Xg21OQfZW9c'.strip()
sheet_name_2 = 'CO2_emission'
url_2 = f'https://docs.google.com/spreadsheets/d/{sheet_ID_2}/gviz/tq?tqx=out:csv&sheet={sheet_name_2}'

# %%
datos_CO2= pd.read_csv(url_2)
datos_CO2
# Out:
#      Country Name country_code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 210         Samoa          WSM         East Asia & Pacific
# 211   Yemen, Rep.          YEM  Middle East & North Africa
# 212  South Africa          ZAF          Sub-Saharan Africa
# 213        Zambia          ZMB          Sub-Saharan Africa
# 214      Zimbabwe          ZWE          Sub-Saharan Africa
#
#                              Indicator Name           1990           1991  \
# 0    CO2 emissions (metric tons per capita)            NaN            NaN
# 1    CO2 emissions (metric tons per capita)    191.745.115    167.681.579
# ...

# %% [markdown]
# ## Leyendo Archivos JSON

# %% [markdown]
# #### Importando archivos JSON

# %%
# Es facil de transmitir los datos muy rapidos
# Se divide en llave y valor

import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-5-2358229096.py in <cell line: 0>()
#       2 # Se divide en llave y valor
#       3
# ----> 4 import pandas as pd
#
# /usr/local/lib/python3.11/dist-packages/pandas/__init__.py in <module>
#     136 )
#     137
# --> 138 from pandas import api, arrays, errors, io, plotting, tseries
#     139 from pandas import testing
#     140 from pandas.util._print_versions import show_versions
#
# /usr/local/lib/python3.11/dist-packages/pandas/api/__init__.py in <module>
#       1 """ public toolkit API """
# ----> 2 from pandas.api import (
#       3     extensions,
#       4     indexers,
#       5     interchange,
#
# /usr/local/lib/python3.11/dist-packages/pandas/api/typing/__init__.py in <module>
#      29 # TODO: Can't import Styler without importing jinja2
#      30 # from pandas.io.formats.style import Styler
# ...

# %%
datos_pacientes= pd.read_json('datos_sus.json') # Leer el archivo JSON, sin información anidada

# %%
datos_pacientes  # Llamamos la variable datos pacientes

# %%
datos_pacientes_2= pd.read_json('datos_sus.json') # Leer el archivo JSON, con información anidada

# %%
datos_pacientes_2

# %% [markdown]
# #### Normalizando Archivos

# %%
de_normalizado = pd.json_normalize(datos_pacientes_2['Pacientes'])  # Esta función de pandas convierte datos JSON anidados en un DataFrame plano. Extrae diccionarios anidados

# %%
de_normalizado.to_json('Historico Pacientes.json')  # Exportamos los datos en archivo JSON

# %%
pd.read_json('Historico Pacientes.json')  # Leemos el archivo JSON

# %% [markdown]
# ## Ejercicio Importando datos JSON

# %%
# Importar modulo JSON
import requests
import json

# %%
# Los datos de API Fruitvice se obtendrán con la función request.get('url'). Dentro de ella pasamos la dirección API seguida de api/fruit/all para obtener los datos de todas las frutas.
datos_frutas = requests.get('https://fruityvice.com/api/fruit/all')

# %%
# Conseguimos recuperar los resultados utilizando la función json.loads(). Para ello es necesario pasar la variable datos_frutas, previamente creada con el atributo text que devuelve el contenido de la respuesta.
resultado = json.loads(datos_frutas.text)

# %%
#Luego podemos obtener una vista previa del DataFrame.
pd.DataFrame(resultado)
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
df_normalizado_2 = pd.json_normalize(resultado)

# %%
df_normalizado_2
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
df_normalizado_2.to_json('Frutas.json')

# %% [markdown]
# ## Leyendo Paginas en HTML y XML

# %% [markdown]
# #### Importando paginas Web

# %%
import pandas as pd

# %%
datos_html= pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)')  # Este código leee la tabla de una pagina html

# %%
datos_html
# Out:
# [                                                   0
#  0  Largest economies in the world by GDP (nominal...,
#                                                     0  \
#  0  > $20 trillion $10–20 trillion $5–10 trillion ...
#
#                                                     1  \
#  0  $750 billion – $1 trillion $500–750 billion $2...
#
#                                                     2
#  0  $50–100 billion $25–50 billion $5–25 billion <...  ,
#      Country/Territory IMF[1][12]            World Bank[13]             \
#      Country/Territory   Forecast       Year       Estimate       Year
#  0               World  113795678       2025      111326370       2024
#  1       United States   30507217       2025       29184890       2024
#  2               China   19231705  [n 1]2025       18743803  [n 3]2024
#  3             Germany    4744804       2025        4659929       2024
#  4               India    4187017       2025        3912686       2024
# ...

# %%
type(datos_html)
# Out:
# list

# %%
len(datos_html)
# Out:
# 7

# %%
informacion_tabla= datos_html[2]  # conm este código seleccionamos la posición de la tabla
informacion_tabla
# Out:
#     Country/Territory IMF[1][12]            World Bank[13]             \
#     Country/Territory   Forecast       Year       Estimate       Year
# 0               World  113795678       2025      111326370       2024
# 1       United States   30507217       2025       29184890       2024
# 2               China   19231705  [n 1]2025       18743803  [n 3]2024
# 3             Germany    4744804       2025        4659929       2024
# 4               India    4187017       2025        3912686       2024
# ..                ...        ...        ...            ...        ...
# 217          Kiribati        312       2025            308       2024
# 218  Marshall Islands        297       2025            280       2024
# 219             Nauru        169       2025            160       2024
# 220        Montserrat          —          —              —          —
# 221            Tuvalu         65       2025             62       2023
#
#     United Nations[14]
# ...

# %% [markdown]
# #### Escribiendo Archivos HTML

# %%
informacion_tabla.to_html('Tabla_paises.html',index= False)

# %%
pd.read_html('Tabla_paises.html')
# Out:
# [    Country/Territory IMF[1][12]            World Bank[13]             \
#      Country/Territory   Forecast       Year       Estimate       Year
#  0               World  113795678       2025      111326370       2024
#  1       United States   30507217       2025       29184890       2024
#  2               China   19231705  [n 1]2025       18743803  [n 3]2024
#  3             Germany    4744804       2025        4659929       2024
#  4               India    4187017       2025        3912686       2024
#  ..                ...        ...        ...            ...        ...
#  217          Kiribati        312       2025            308       2024
#  218  Marshall Islands        297       2025            280       2024
#  219             Nauru        169       2025            160       2024
#  220        Montserrat        â        â            â        â
#  221            Tuvalu         65       2025             62       2023
#
#      United Nations[14]
# ...

# %%
informacion_tabla.to_csv('Tabla_paises.csv', index= False)  # Exportar archivo a CSV

# %%
datos = pd.read_csv('Tabla_paises.csv')
datos
# Out:
#      Country/Territory IMF[1][12] IMF[1][12].1 World Bank[13]  \
# 0    Country/Territory   Forecast         Year       Estimate
# 1                World  113795678         2025      111326370
# 2        United States   30507217         2025       29184890
# 3                China   19231705    [n 1]2025       18743803
# 4              Germany    4744804         2025        4659929
# ..                 ...        ...          ...            ...
# 218           Kiribati        312         2025            308
# 219   Marshall Islands        297         2025            280
# 220              Nauru        169         2025            160
# 221         Montserrat          —            —              —
# 222             Tuvalu         65         2025             62
#
#     World Bank[13].1 United Nations[14] United Nations[14].1
# 0               Year           Estimate                 Year
# 1               2024          100834796                 2022
# ...

# %% [markdown]
# ## Leyendo Archivos XML

# %%
# Leyendo archivos XML

import pandas as pd

# %%
datos_imbd= pd.read_xml('simple.xml')  # Leer archivo XML

# %%
datos_imbd
# Out:
#                           name  price  \
# 0              Belgian Waffles  $5.95
# 1   Strawberry Belgian Waffles  $7.95
# 2  Berry-Berry Belgian Waffles  $8.95
# 3                 French Toast  $4.50
# 4          Homestyle Breakfast  $6.95
#
#                                          description  calories
# 0  Two of our famous Belgian Waffles with plenty ...       650
# 1  Light Belgian waffles covered with strawberrie...       900
# 2  Light Belgian waffles covered with an assortme...       900
# 3  Thick slices made from our homemade sourdough ...       600
# 4  Two eggs, bacon or sausage, toast, and our eve...       950

# %%
datos_imbd.head(3)
# Out:
#                           name  price  \
# 0              Belgian Waffles  $5.95
# 1   Strawberry Belgian Waffles  $7.95
# 2  Berry-Berry Belgian Waffles  $8.95
#
#                                          description  calories
# 0  Two of our famous Belgian Waffles with plenty ...       650
# 1  Light Belgian waffles covered with strawberrie...       900
# 2  Light Belgian waffles covered with an assortme...       900

# %%
datos_imbd.to_xml('simple_2.xml')  # Exportar archivo XML

# %%
datos_imbd_2= pd.read_xml('simple_2.xml')

# %%
datos_imbd_2
# Out:
#    index                         name  price  \
# 0      0              Belgian Waffles  $5.95
# 1      1   Strawberry Belgian Waffles  $7.95
# 2      2  Berry-Berry Belgian Waffles  $8.95
# 3      3                 French Toast  $4.50
# 4      4          Homestyle Breakfast  $6.95
#
#                                          description  calories
# 0  Two of our famous Belgian Waffles with plenty ...       650
# 1  Light Belgian waffles covered with strawberrie...       900
# 2  Light Belgian waffles covered with an assortme...       900
# 3  Thick slices made from our homemade sourdough ...       600
# 4  Two eggs, bacon or sausage, toast, and our eve...       950

# %% [markdown]
# ## Haga lo que hicimos

# %%
import pandas as pd

# %%
info_poblacion = pd.read_html('poblacion.html')

# %%
info_poblacion
# Out:
# [     N.º                   País (o territorio dependiente)  \
#  0      1                                             India
#  1      2                                        China[12]​
#  2      3                                    Estados Unidos
#  3      4                                         Indonesia
#  4      5                                          Pakistán
#  ..   ...                                               ...
#  241  242                           Islas Cocos (Australia)
#  242  243  Islas Ultramarinas Menores de los Estados Unidos
#  243  244                               Islas Pitcairn (RU)
#  244  NaN                                             Mundo
#  245   N°                   País (o territorio dependiente)
#
#      Proyección exponencial de la población al 1/7/2025[7]​  \
#  0                                        1 417 492 000
#  1                                        1 407 934 000
#  2                                          342 181 000
# ...

# %%
type(info_poblacion)
# Out:
# list

# %%
len(info_poblacion)
# Out:
# 7

# %%
info_poblacion_2= info_poblacion[0]
info_poblacion_2
# Out:
#      N.º                   País (o territorio dependiente)  \
# 0      1                                             India
# 1      2                                        China[12]​
# 2      3                                    Estados Unidos
# 3      4                                         Indonesia
# 4      5                                          Pakistán
# ..   ...                                               ...
# 241  242                           Islas Cocos (Australia)
# 242  243  Islas Ultramarinas Menores de los Estados Unidos
# 243  244                               Islas Pitcairn (RU)
# 244  NaN                                             Mundo
# 245   N°                   País (o territorio dependiente)
#
#     Proyección exponencial de la población al 1/7/2025[7]​  \
# 0                                        1 417 492 000
# 1                                        1 407 934 000
# 2                                          342 181 000
# ...

# %%
info_poblacion_2.to_csv('Poblacion.csv', index= False)

# %%
info_poblacion_3= pd.read_csv('Poblacion.csv')
info_poblacion_3
# Out:
#      N.º                   País (o territorio dependiente)  \
# 0      1                                             India
# 1      2                                        China[12]​
# 2      3                                    Estados Unidos
# 3      4                                         Indonesia
# 4      5                                          Pakistán
# ..   ...                                               ...
# 241  242                           Islas Cocos (Australia)
# 242  243  Islas Ultramarinas Menores de los Estados Unidos
# 243  244                               Islas Pitcairn (RU)
# 244  NaN                                             Mundo
# 245   N°                   País (o territorio dependiente)
#
#     Proyección exponencial de la población al 1/7/2025[7]​  \
# 0                                        1 417 492 000
# 1                                        1 407 934 000
# 2                                          342 181 000
# ...
